# %% [markdown]
# # Predictive Analysis #2
#
# ### In this notebook we will explore prototype and evaluate a many to one LSTM model for timeseries prediction

# %%
import os
import sys
import math

import cufflinks
import numpy as np
import pandas as pd
# Standard plotly imports
import plotly.graph_objs as go
import seaborn as sns
from keras.layers import Dense
from keras.layers import LSTM
# univariate convlstm example
from keras.models import Sequential
from plotly.offline import iplot, init_notebook_mode
from sklearn import preprocessing

# Using plotly + cufflinks in offline mode
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

sns.set_context("notebook", font_scale=1.)
sns.set_style("whitegrid")

# Using plotly + cufflinks in offline mode
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

DATASET_PATH = module_path + "/notebook/dt_agg1hour.h5"

dataset = pd.read_pickle(
    DATASET_PATH)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from src.modeling import lstmModel
from src.processing import dataProc

lstmodel = lstmModel()

start_date = '2015-11-10'
end_date = '2015-11-25'

dataset = pd.read_pickle(
    DATASET_PATH)
dataset = dataset[start_date:end_date]
dataset = dataProc.create_features(dataset= dataset)

lstmodel.train(dataset=dataset, evaluate=True)
y_pred, y = lstmodel.generate_prediction(input_data= dataset)
for idx, i in enumerate(y_pred):
    print(math.ceil(i), y[idx])

# plot history
# Out:
# Train on 344 samples, validate on 39 samples
# Epoch 1/100
#  - 2s - loss: 0.0481 - val_loss: 0.0431
# Epoch 2/100
#  - 0s - loss: 0.0451 - val_loss: 0.0409
# Epoch 3/100
#  - 0s - loss: 0.0436 - val_loss: 0.0401
# Epoch 4/100
#  - 0s - loss: 0.0421 - val_loss: 0.0393
# Epoch 5/100
#  - 0s - loss: 0.0410 - val_loss: 0.0385
# Epoch 6/100
#  - 0s - loss: 0.0397 - val_loss: 0.0377
# Epoch 7/100
#  - 0s - loss: 0.0385 - val_loss: 0.0367
# Epoch 8/100
#  - 0s - loss: 0.0375 - val_loss: 0.0358
# Epoch 9/100
#  - 0s - loss: 0.0368 - val_loss: 0.0354
# Epoch 10/100
#  - 0s - loss: 0.0362 - val_loss: 0.0348
# Epoch 11/100
#  - 0s - loss: 0.0358 - val_loss: 0.0343
# Epoch 12/100
#  - 0s - loss: 0.0355 - val_loss: 0.0342
# Epoch 13/100
#  - 0s - loss: 0.0354 - val_loss: 0.0342
# Epoch 14/100
#  - 0s - loss: 0.0354 - val_loss: 0.0343
# Epoch 15/100
#  - 0s - loss: 0.0354 - val_loss: 0.0343
# Epoch 16/100
#  - 0s - loss: 0.0355 - val_loss: 0.0343
# Epoch 17/100
#  - 0s - loss: 0.0355 - val_loss: 0.0344
# Epoch 18/100
#  - 0s - loss: 0.0348 - val_loss: 0.0345
# Epoch 19/100
#  - 0s - loss: 0.0345 - val_loss: 0.0347
# Epoch 20/100
#  - 0s - loss: 0.0343 - val_loss: 0.0348
# Epoch 21/100
#  - 0s - loss: 0.0341 - val_loss: 0.0348
# Epoch 22/100
#  - 0s - loss: 0.0342 - val_loss: 0.0350
# Epoch 23/100
#  - 0s - loss: 0.0341 - val_loss: 0.0350
# Epoch 24/100
#  - 0s - loss: 0.0341 - val_loss: 0.0351
# Epoch 25/100
#  - 0s - loss: 0.0339 - val_loss: 0.0351
# Epoch 26/100
#  - 0s - loss: 0.0344 - val_loss: 0.0356
# Epoch 27/100
#  - 0s - loss: 0.0338 - val_loss: 0.0352
# Epoch 28/100
#  - 0s - loss: 0.0343 - val_loss: 0.0363
# Epoch 29/100
#  - 0s - loss: 0.0339 - val_loss: 0.0351
# Epoch 30/100
#  - 0s - loss: 0.0342 - val_loss: 0.0371
# Epoch 31/100
#  - 0s - loss: 0.0339 - val_loss: 0.0358
# Epoch 32/100
#  - 0s - loss: 0.0339 - val_loss: 0.0352
# Epoch 33/100
#  - 0s - loss: 0.0337 - val_loss: 0.0354
# Epoch 34/100
#  - 0s - loss: 0.0342 - val_loss: 0.0372
# Epoch 35/100
#  - 0s - loss: 0.0339 - val_loss: 0.0363
# Epoch 36/100
#  - 0s - loss: 0.0341 - val_loss: 0.0353
# Epoch 37/100
#  - 0s - loss: 0.0338 - val_loss: 0.0362
# Epoch 38/100
#  - 0s - loss: 0.0342 - val_loss: 0.0370
# Epoch 39/100
#  - 0s - loss: 0.0340 - val_loss: 0.0360
# Epoch 40/100
#  - 0s - loss: 0.0339 - val_loss: 0.0358
# Epoch 41/100
#  - 0s - loss: 0.0335 - val_loss: 0.0353
# Epoch 42/100
#  - 0s - loss: 0.0338 - val_loss: 0.0362
# Epoch 43/100
#  - 0s - loss: 0.0336 - val_loss: 0.0365
# Epoch 44/100
#  - 0s - loss: 0.0339 - val_loss: 0.0349
# Epoch 45/100
#  - 0s - loss: 0.0339 - val_loss: 0.0348
# Epoch 46/100
#  - 0s - loss: 0.0334 - val_loss: 0.0349
# Epoch 47/100
#  - 0s - loss: 0.0334 - val_loss: 0.0350
# Epoch 48/100
#  - 0s - loss: 0.0335 - val_loss: 0.0349
# Epoch 49/100
#  - 0s - loss: 0.0337 - val_loss: 0.0348
# Epoch 50/100
#  - 0s - loss: 0.0333 - val_loss: 0.0349
# Epoch 51/100
#  - 0s - loss: 0.0333 - val_loss: 0.0349
# Epoch 52/100
#  - 0s - loss: 0.0338 - val_loss: 0.0365
# Epoch 53/100
#  - 0s - loss: 0.0336 - val_loss: 0.0358
# Epoch 54/100
#  - 0s - loss: 0.0337 - val_loss: 0.0363
# Epoch 55/100
#  - 0s - loss: 0.0335 - val_loss: 0.0356
# Epoch 56/100
#  - 0s - loss: 0.0336 - val_loss: 0.0361
# Epoch 57/100
#  - 0s - loss: 0.0333 - val_loss: 0.0353
# Epoch 58/100
#  - 0s - loss: 0.0335 - val_loss: 0.0366
# Epoch 59/100
#  - 0s - loss: 0.0333 - val_loss: 0.0356
# Epoch 60/100
#  - 0s - loss: 0.0335 - val_loss: 0.0353
# Epoch 61/100
#  - 0s - loss: 0.0331 - val_loss: 0.0347
# Epoch 62/100
#  - 0s - loss: 0.0333 - val_loss: 0.0346
# Epoch 63/100
#  - 0s - loss: 0.0332 - val_loss: 0.0351
# Epoch 64/100
#  - 0s - loss: 0.0332 - val_loss: 0.0353
# Epoch 65/100
#  - 0s - loss: 0.0334 - val_loss: 0.0358
# Epoch 66/100
#  - 0s - loss: 0.0333 - val_loss: 0.0358
# Epoch 67/100
#  - 0s - loss: 0.0336 - val_loss: 0.0361
# Epoch 68/100
#  - 0s - loss: 0.0332 - val_loss: 0.0352
# Epoch 69/100
#  - 0s - loss: 0.0332 - val_loss: 0.0355
# Epoch 70/100
#  - 0s - loss: 0.0331 - val_loss: 0.0350
# Epoch 71/100
#  - 0s - loss: 0.0331 - val_loss: 0.0349
# Epoch 72/100
#  - 0s - loss: 0.0330 - val_loss: 0.0354
# Epoch 73/100
#  - 0s - loss: 0.0333 - val_loss: 0.0348
# Epoch 74/100
#  - 0s - loss: 0.0333 - val_loss: 0.0344
# Epoch 75/100
#  - 0s - loss: 0.0330 - val_loss: 0.0347
# Epoch 76/100
#  - 0s - loss: 0.0331 - val_loss: 0.0347
# Epoch 77/100
#  - 0s - loss: 0.0331 - val_loss: 0.0350
# Epoch 78/100
#  - 0s - loss: 0.0329 - val_loss: 0.0350
# Epoch 79/100
#  - 0s - loss: 0.0331 - val_loss: 0.0348
# Epoch 80/100
#  - 0s - loss: 0.0330 - val_loss: 0.0344
# Epoch 81/100
#  - 0s - loss: 0.0328 - val_loss: 0.0344
# Epoch 82/100
#  - 0s - loss: 0.0329 - val_loss: 0.0342
# Epoch 83/100
#  - 0s - loss: 0.0329 - val_loss: 0.0342
# Epoch 84/100
#  - 0s - loss: 0.0331 - val_loss: 0.0343
# Epoch 85/100
#  - 0s - loss: 0.0327 - val_loss: 0.0341
# Epoch 86/100
#  - 0s - loss: 0.0329 - val_loss: 0.0342
# Epoch 87/100
#  - 0s - loss: 0.0327 - val_loss: 0.0340
# Epoch 88/100
#  - 0s - loss: 0.0329 - val_loss: 0.0342
# Epoch 89/100
#  - 0s - loss: 0.0327 - val_loss: 0.0346
# Epoch 90/100
#  - 0s - loss: 0.0328 - val_loss: 0.0348
# Epoch 91/100
#  - 0s - loss: 0.0329 - val_loss: 0.0347
# Epoch 92/100
#  - 0s - loss: 0.0326 - val_loss: 0.0342
# Epoch 93/100
#  - 0s - loss: 0.0329 - val_loss: 0.0345
# Epoch 94/100
#  - 0s - loss: 0.0325 - val_loss: 0.0340
# Epoch 95/100
#  - 0s - loss: 0.0329 - val_loss: 0.0342
# Epoch 96/100
#  - 0s - loss: 0.0326 - val_loss: 0.0342
# Epoch 97/100
#  - 0s - loss: 0.0327 - val_loss: 0.0341
# Epoch 98/100
#  - 0s - loss: 0.0328 - val_loss: 0.0340
# Epoch 99/100
#  - 0s - loss: 0.0328 - val_loss: 0.0345
# Epoch 100/100
#  - 0s - loss: 0.0325 - val_loss: 0.0341
# (39, 4) [[0.00522379 0.         0.16666667 0.3478261 ]
#  [0.00415529 0.         0.16666667 0.39130434]
#  [0.01828327 0.         0.16666667 0.43478262]
#  [0.0495073  0.         0.16666667 0.47826087]
#  [0.18212038 0.         0.16666667 0.5217391 ]
#  [0.17654042 0.         0.16666667 0.5652174 ]
#  [0.06066722 0.         0.16666667 0.6086957 ]
#  [0.04179034 0.         0.16666667 0.65217394]
#  [0.03324231 0.         0.16666667 0.6956522 ]
#  [0.0352606  0.         0.16666667 0.73913044]
#  [0.04143417 0.         0.16666667 0.7826087 ]
#  [0.04392734 0.         0.16666667 0.826087  ]
#  [0.04380862 0.         0.16666667 0.86956525]
#  [0.05259408 0.         0.16666667 0.9130435 ]
#  [0.09652143 0.         0.16666667 0.95652175]
#  [0.15291463 0.         0.16666667 1.        ]
#  [0.09925205 0.         0.33333334 0.        ]
#  [0.35818592 0.         0.33333334 0.04347826]
#  [0.19969131 0.         0.33333334 0.08695652]
#  [0.07966283 0.         0.33333334 0.13043478]
#  [0.0626855  0.         0.33333334 0.17391305]
#  [0.03561676 0.         0.33333334 0.21739131]
#  [0.01543393 0.         0.33333334 0.26086956]
#  [0.00795441 0.         0.33333334 0.30434784]
#  [0.00641102 0.         0.33333334 0.3478261 ]
#  [0.00391784 0.         0.33333334 0.39130434]
#  [0.00712335 0.         0.33333334 0.43478262]
#  [0.04380862 0.         0.33333334 0.47826087]
#  [0.19031224 0.         0.33333334 0.5217391 ]
#  [0.17832126 0.         0.33333334 0.5652174 ]
#  [0.05734299 0.         0.33333334 0.6086957 ]
#  [0.0373976  0.         0.33333334 0.65217394]
#  [0.03585421 0.         0.33333334 0.6956522 ]
#  [0.03977205 0.         0.33333334 0.73913044]
#  [0.03917844 0.         0.33333334 0.7826087 ]
#  [0.04998219 0.         0.33333334 0.826087  ]
#  [0.04832007 0.         0.33333334 0.86956525]
#  [0.0568681  0.         0.33333334 0.9130435 ]
#  [0.10103289 0.         0.33333334 0.95652175]]
# Test RMSE: 535.380
# (383, 4) [[0.08643001 0.         0.16666667 0.        ]
#  [0.06197317 0.         0.16666667 0.04347826]
#  [0.06446634 0.         0.16666667 0.08695652]
#  ...
#  [0.04832007 0.         0.33333334 0.86956525]
#  [0.0568681  0.         0.33333334 0.9130435 ]
#  [0.10103289 0.         0.33333334 0.95652175]]
# Test RMSE: 656.800
# 580 557.0
# 427 578.0
# 431 577.0
# 423 385.0
# 287 222.0
# 173 123.00001
# 105 63.0
# 67 67.0
# 74 35.0
# 60 95.0
# 109 433.99997
# 344 1337.0
# 930 1273.0
# 901 503.0
# 430 330.99997
# 337 279.0
# 323 285.0
# 349 304.0
# 385 329.0
# 427 360.0
# 474 432.0
# 548 684.0
# 733 1209.0
# 1076 873.0
# 696 645.0
# 522 723.0
# 564 696.0
# 535 424.0
# 339 294.0
# 243 160.0
# 147 57.0
# 75 94.0
# 104 57.0
# 83 74.0
# 102 387.0
# 325 1427.0
# 1014 1735.0
# 1214 507.0
# 441 336.0
# 343 286.0
# 329 255.0
# 329 303.0
# 383 402.0
# 471 375.0
# 480 426.0
# 540 820.0
# 816 1349.0
# 1167 978.0
# 815 634.0
# 552 690.0
# 578 735.0
# 598 489.0
# 413 330.0
# 293 168.0
# 172 115.0
# 133 99.0
# 122 55.0
# 94 79.0
# 116 485.0
# 407 1492.0
# 1088 1437.0
# 1058 491.0
# 441 370.0
# 373 313.0
# 351 390.0
# 422 314.0
# 391 329.0
# 424 391.0
# 490 449.0
# 554 894.0
# 868 2256.0
# 1719 1181.0
# 1012 750.0
# 679 716.0
# 638 809.0
# 692 695.0
# 597 388.0
# 363 265.0
# 267 169.0
# 193 117.00001
# 153 89.0
# 134 78.0
# 129 383.0
# 354 1730.0
# 1281 2073.0
# 1507 583.0
# 519 417.0
# 416 342.0
# 379 416.0
# 447 397.0
# 453 467.0
# 521 480.0
# 552 590.0
# 650 1041.0
# 971 4701.0
# 3089 4726.0
# 3424 3787.0
# 2822 1630.0
# 1352 958.0
# 846 3096.0
# 2308 1547.0
# 1242 946.0
# 800 884.0
# 747 585.0
# 1274 330.99997
# 359 199.0
# 260 254.0
# 305 285.0
# 334 247.0
# 313 297.0
# 360 357.0
# 415 411.0
# 468 408.0
# 481 472.0
# 544 383.0
# 500 374.0
# 515 423.0
# 573 497.0
# 650 556.0
# 406 578.0
# 411 605.0
# 421 605.0
# 415 517.0
# 354 299.0
# 208 129.0
# 97 97.0
# 80 91.0
# 83 64.0
# 74 118.0
# 120 823.0
# 581 3945.0
# 2345 2975.0
# 1847 648.0
# 515 438.0
# 403 280.0
# 326 343.0
# 389 303.0
# 389 395.0
# 473 421.0
# 518 433.99997
# 556 865.0
# 843 1310.0
# 1129 800.0
# 605 644.0
# 486 725.0
# 531 794.0
# 569 453.0
# 333 268.0
# 205 134.0
# 113 71.0
# 72 79.0
# 83 70.0
# 83 189.0
# 172 452.0
# 356 1569.0
# 1073 1522.0
# 1054 546.0
# 457 387.0
# 373 315.0
# 346 332.0
# 379 383.99997
# 436 405.0
# 475 404.0
# 501 478.0
# 576 848.0
# 832 1323.0
# 1142 871.00006
# 695 3052.0
# 2097 1717.0
# 1236 706.0
# 542 563.0
# 436 335.0
# 272 165.0
# 150 102.00001
# 107 89.0
# 101 68.0
# 91 95.0
# 117 404.0
# 336 1638.0
# 1147 1537.0
# 1091 518.0
# 448 350.0
# 353 337.0
# 362 370.0
# 404 365.0
# 423 456.0
# 506 442.0
# 523 514.0
# 596 886.0
# 857 1475.0
# <div>
#
#
#             <div id="ba94efe7-e8b5-42d8-b117-b239713e9af9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ba94efe7-e8b5-42d8-b117-b239713e9af9")) {
#                     Plotly.newPlot(
#                         'ba94efe7-e8b5-42d8-b117-b239713e9af9',
#                         [{"mode": "lines", "name": "predicted", "type": "scatter", "uid": "49cefd88-bd5c-4b00-962e-cc1a9fbfca07", "y": [579.5267333984375, 426.2533264160156, 430.8240051269531, 422.4645690917969, 286.5408020019531, 172.61500549316406, 104.92804718017578, 66.40696716308594, 73.89543151855469, 59.066715240478516, 108.47457122802734, 343.79779052734375, 929.4570922851562, 900.4195556640625, 429.2257080078125, 336.2034912109375, 322.7861328125, 348.7366943359375, 384.8171081542969, 426.4232482910156, 473.4505920410156, 547.4840087890625, 732.3623657226562, 1075.5538330078125, 695.4998168945312, 521.4706420898438, 563.7813110351562, 534.9390258789062, 338.0857238769531, 242.4655303955078, 146.47882080078125, 74.73487091064453, 103.5286865234375, 82.74637603759766, 101.66082763671875, 324.2384948730469, 1013.40283203125, 1213.884033203125, 440.1275939941406, 342.9827880859375, 328.3025817871094, 328.3945007324219, 382.3385925292969, 470.7444152832031, 479.238525390625, 539.6142578125, 815.882080078125, 1166.09912109375, 814.8668212890625, 551.8511352539062, 577.9612426757812, 597.9452514648438, 412.9974060058594, 292.298583984375, 171.787353515625, 132.2500762939453, 121.66812896728516, 93.34671020507812, 115.73440551757812, 406.6097412109375, 1087.21826171875, 1057.977783203125, 440.6810302734375, 372.72515869140625, 350.6492614746094, 421.2290954589844, 390.7896423339844, 423.46893310546875, 489.037841796875, 553.29248046875, 867.0328369140625, 1718.685546875, 1011.8029174804688, 678.7821044921875, 637.5026245117188, 691.0677490234375, 596.2969970703125, 362.9142150878906, 266.3440856933594, 192.14971923828125, 152.81442260742188, 133.48101806640625, 