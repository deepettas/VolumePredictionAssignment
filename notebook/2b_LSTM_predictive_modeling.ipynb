# %% [markdown]
# # Predictive Analysis #2
#
# ### In this notebook we will explore prototype and evaluate a many to one LSTM model for timeseries prediction

# %%
import os
import sys
import math

import cufflinks
import numpy as np
import pandas as pd
# Standard plotly imports
import plotly.graph_objs as go
import seaborn as sns
from keras.layers import Dense
from keras.layers import LSTM
# univariate convlstm example
from keras.models import Sequential
from plotly.offline import iplot, init_notebook_mode
from sklearn import preprocessing

# Using plotly + cufflinks in offline mode
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

sns.set_context("notebook", font_scale=1.)
sns.set_style("whitegrid")

# Using plotly + cufflinks in offline mode
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.modeling import lstmModel
from src.processing import dataProc

DATASET_PATH = module_path + "/notebook/dt_agg1hour.h5"

dataset = pd.read_pickle(
    DATASET_PATH)
# Out:
# Error importing optional module geopandas
# Traceback (most recent call last):
#   File "/Users/noresources/Pycharm_projects/justbeatit/venv/lib/python3.7/site-packages/_plotly_utils/optional_imports.py", line 25, in get_module
#     return import_module(name)
#   File "/Users/noresources/anaconda3/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/noresources/Pycharm_projects/justbeatit/venv/lib/python3.7/site-packages/geopandas/__init__.py", line 1, in <module>
#     from geopandas.geoseries import GeoSeries
#   File "/Users/noresources/Pycharm_projects/justbeatit/venv/lib/python3.7/site-packages/geopandas/geoseries.py", line 13, in <module>
#     from geopandas.base import GeoPandasBase, _unary_op, _CoordinateIndexer
#   File "/Users/noresources/Pycharm_projects/justbeatit/venv/lib/python3.7/site-packages/geopandas/base.py", line 17, in <module>
#     from rtree.core import RTreeError
#   File "/Users/noresources/Pycharm_projects/justbeatit/venv/lib/python3.7/site-packages/rtree/__init__.py", line 1, in <module>
#     from .index import Rtree
#   File "/Users/noresources/Pycharm_projects/justbeatit/venv/lib/python3.7/site-packages/rtree/index.py", line 5, in <module>
#     from . import core
#   File "/Users/noresources/Pycharm_projects/justbeatit/venv/lib/python3.7/site-packages/rtree/core.py", line 125, in <module>
#     raise OSError("Could not find libspatialindex_c library file")
# OSError: Could not find libspatialindex_c library file
# Using TensorFlow backend.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
lstmodel = lstmModel()

start_date = '2015-11-10'
end_date = '2015-11-25'

dataset = pd.read_pickle(
    DATASET_PATH)
dataset = dataset[start_date:end_date]
dataset = dataProc.create_features(dataset= dataset)

dataset
# Out:
#                      ride_volume  month_of_year  day_of_week  hour_of_day
# request_date
# 2015-11-10 00:00:00          763             11            1            0
# 2015-11-10 01:00:00          557             11            1            1
# 2015-11-10 02:00:00          578             11            1            2
# 2015-11-10 03:00:00          577             11            1            3
# 2015-11-10 04:00:00          385             11            1            4
# 2015-11-10 05:00:00          222             11            1            5
# 2015-11-10 06:00:00          123             11            1            6
# 2015-11-10 07:00:00           63             11            1            7
# 2015-11-10 08:00:00           67             11            1            8
# 2015-11-10 09:00:00           35             11            1            9
# 2015-11-10 10:00:00           95             11            1           10
# 2015-11-10 11:00:00          434             11            1           11
# 2015-11-10 12:00:00         1337             11            1           12
# 2015-11-10 13:00:00         1273             11            1           13
# 2015-11-10 14:00:00          503             11            1           14
# 2015-11-10 15:00:00          331             11            1           15
# 2015-11-10 16:00:00          279             11            1           16
# 2015-11-10 17:00:00          285             11            1           17
# 2015-11-10 18:00:00          304             11            1           18
# 2015-11-10 19:00:00          329             11            1           19
# 2015-11-10 20:00:00          360             11            1           20
# 2015-11-10 21:00:00          432             11            1           21
# 2015-11-10 22:00:00          684             11            1           22
# 2015-11-10 23:00:00         1209             11            1           23
# 2015-11-11 00:00:00          873             11            2            0
# 2015-11-11 01:00:00          645             11            2            1
# 2015-11-11 02:00:00          723             11            2            2
# 2015-11-11 03:00:00          696             11            2            3
# 2015-11-11 04:00:00          424             11            2            4
# 2015-11-11 05:00:00          294             11            2            5
# ...                          ...            ...          ...          ...
# 2015-11-24 18:00:00          384             11            1           18
# 2015-11-24 19:00:00          405             11            1           19
# 2015-11-24 20:00:00          404             11            1           20
# 2015-11-24 21:00:00          478             11            1           21
# 2015-11-24 22:00:00          848             11            1           22
# 2015-11-24 23:00:00         1323             11            1           23
# 2015-11-25 00:00:00          871             11            2            0
# 2015-11-25 01:00:00         3052             11            2            1
# 2015-11-25 02:00:00         1717             11            2            2
# 2015-11-25 03:00:00          706             11            2            3
# 2015-11-25 04:00:00          563             11            2            4
# 2015-11-25 05:00:00          335             11            2            5
# 2015-11-25 06:00:00          165             11            2            6
# 2015-11-25 07:00:00          102             11            2            7
# 2015-11-25 08:00:00           89             11            2            8
# 2015-11-25 09:00:00           68             11            2            9
# 2015-11-25 10:00:00           95             11            2           10
# 2015-11-25 11:00:00          404             11            2           11
# 2015-11-25 12:00:00         1638             11            2           12
# 2015-11-25 13:00:00         1537             11            2           13
# 2015-11-25 14:00:00          518             11            2           14
# 2015-11-25 15:00:00          350             11            2           15
# 2015-11-25 16:00:00          337             11            2           16
# 2015-11-25 17:00:00          370             11            2           17
# 2015-11-25 18:00:00          365             11            2           18
# 2015-11-25 19:00:00          456             11            2           19
# 2015-11-25 20:00:00          442             11            2           20
# 2015-11-25 21:00:00          514             11            2           21
# 2015-11-25 22:00:00          886             11            2           22
# 2015-11-25 23:00:00         1475             11            2           23
#
# [384 rows x 4 columns]

# %%
lstmodel.train(dataset=dataset, evaluate=True)
y_pred, y = lstmodel.generate_prediction(input_data= dataset)
# Out:
# Train on 344 samples, validate on 39 samples
# Epoch 1/100
# 344/344 - 1s - loss: 0.0530 - val_loss: 0.0458
# Epoch 2/100
# 344/344 - 0s - loss: 0.0494 - val_loss: 0.0442
# Epoch 3/100
# 344/344 - 0s - loss: 0.0474 - val_loss: 0.0430
# Epoch 4/100
# 344/344 - 0s - loss: 0.0459 - val_loss: 0.0420
# Epoch 5/100
# 344/344 - 0s - loss: 0.0448 - val_loss: 0.0413
# Epoch 6/100
# 344/344 - 0s - loss: 0.0438 - val_loss: 0.0405
# Epoch 7/100
# 344/344 - 0s - loss: 0.0429 - val_loss: 0.0399
# Epoch 8/100
# 344/344 - 0s - loss: 0.0419 - val_loss: 0.0392
# Epoch 9/100
# 344/344 - 0s - loss: 0.0407 - val_loss: 0.0384
# Epoch 10/100
# 344/344 - 0s - loss: 0.0396 - val_loss: 0.0376
# Epoch 11/100
# 344/344 - 0s - loss: 0.0385 - val_loss: 0.0366
# Epoch 12/100
# 344/344 - 0s - loss: 0.0375 - val_loss: 0.0357
# Epoch 13/100
# 344/344 - 0s - loss: 0.0366 - val_loss: 0.0349
# Epoch 14/100
# 344/344 - 0s - loss: 0.0360 - val_loss: 0.0345
# Epoch 15/100
# 344/344 - 0s - loss: 0.0357 - val_loss: 0.0343
# Epoch 16/100
# 344/344 - 0s - loss: 0.0355 - val_loss: 0.0340
# Epoch 17/100
# 344/344 - 0s - loss: 0.0354 - val_loss: 0.0342
# Epoch 18/100
# 344/344 - 0s - loss: 0.0353 - val_loss: 0.0340
# Epoch 19/100
# 344/344 - 0s - loss: 0.0351 - val_loss: 0.0340
# Epoch 20/100
# 344/344 - 0s - loss: 0.0350 - val_loss: 0.0341
# Epoch 21/100
# 344/344 - 0s - loss: 0.0352 - val_loss: 0.0342
# Epoch 22/100
# 344/344 - 0s - loss: 0.0352 - val_loss: 0.0344
# Epoch 23/100
# 344/344 - 0s - loss: 0.0348 - val_loss: 0.0346
# Epoch 24/100
# 344/344 - 0s - loss: 0.0343 - val_loss: 0.0345
# Epoch 25/100
# 344/344 - 0s - loss: 0.0342 - val_loss: 0.0347
# Epoch 26/100
# 344/344 - 0s - loss: 0.0340 - val_loss: 0.0347
# Epoch 27/100
# 344/344 - 0s - loss: 0.0340 - val_loss: 0.0350
# Epoch 28/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0348
# Epoch 29/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0353
# Epoch 30/100
# 344/344 - 0s - loss: 0.0338 - val_loss: 0.0350
# Epoch 31/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0353
# Epoch 32/100
# 344/344 - 0s - loss: 0.0338 - val_loss: 0.0361
# Epoch 33/100
# 344/344 - 0s - loss: 0.0340 - val_loss: 0.0354
# Epoch 34/100
# 344/344 - 0s - loss: 0.0338 - val_loss: 0.0358
# Epoch 35/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0349
# Epoch 36/100
# 344/344 - 0s - loss: 0.0341 - val_loss: 0.0354
# Epoch 37/100
# 344/344 - 0s - loss: 0.0336 - val_loss: 0.0349
# Epoch 38/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0369
# Epoch 39/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0364
# Epoch 40/100
# 344/344 - 0s - loss: 0.0341 - val_loss: 0.0349
# Epoch 41/100
# 344/344 - 0s - loss: 0.0340 - val_loss: 0.0354
# Epoch 42/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0349
# Epoch 43/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0368
# Epoch 44/100
# 344/344 - 0s - loss: 0.0337 - val_loss: 0.0357
# Epoch 45/100
# 344/344 - 0s - loss: 0.0337 - val_loss: 0.0355
# Epoch 46/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0354
# Epoch 47/100
# 344/344 - 0s - loss: 0.0337 - val_loss: 0.0362
# Epoch 48/100
# 344/344 - 0s - loss: 0.0336 - val_loss: 0.0358
# Epoch 49/100
# 344/344 - 0s - loss: 0.0339 - val_loss: 0.0360
# Epoch 50/100
# 344/344 - 0s - loss: 0.0336 - val_loss: 0.0351
# Epoch 51/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0356
# Epoch 52/100
# 344/344 - 0s - loss: 0.0334 - val_loss: 0.0350
# Epoch 53/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0351
# Epoch 54/100
# 344/344 - 0s - loss: 0.0334 - val_loss: 0.0355
# Epoch 55/100
# 344/344 - 0s - loss: 0.0337 - val_loss: 0.0354
# Epoch 56/100
# 344/344 - 0s - loss: 0.0336 - val_loss: 0.0350
# Epoch 57/100
# 344/344 - 0s - loss: 0.0336 - val_loss: 0.0352
# Epoch 58/100
# 344/344 - 0s - loss: 0.0336 - val_loss: 0.0349
# Epoch 59/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0354
# Epoch 60/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0349
# Epoch 61/100
# 344/344 - 0s - loss: 0.0334 - val_loss: 0.0351
# Epoch 62/100
# 344/344 - 0s - loss: 0.0333 - val_loss: 0.0348
# Epoch 63/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0355
# Epoch 64/100
# 344/344 - 0s - loss: 0.0333 - val_loss: 0.0349
# Epoch 65/100
# 344/344 - 0s - loss: 0.0334 - val_loss: 0.0359
# Epoch 66/100
# 344/344 - 0s - loss: 0.0333 - val_loss: 0.0354
# Epoch 67/100
# 344/344 - 0s - loss: 0.0334 - val_loss: 0.0353
# Epoch 68/100
# 344/344 - 0s - loss: 0.0334 - val_loss: 0.0349
# Epoch 69/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0352
# Epoch 70/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0347
# Epoch 71/100
# 344/344 - 0s - loss: 0.0335 - val_loss: 0.0346
# Epoch 72/100
# 344/344 - 0s - loss: 0.0334 - val_loss: 0.0345
# Epoch 73/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0346
# Epoch 74/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0344
# Epoch 75/100
# 344/344 - 0s - loss: 0.0331 - val_loss: 0.0345
# Epoch 76/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0346
# Epoch 77/100
# 344/344 - 0s - loss: 0.0331 - val_loss: 0.0348
# Epoch 78/100
# 344/344 - 0s - loss: 0.0331 - val_loss: 0.0344
# Epoch 79/100
# 344/344 - 0s - loss: 0.0331 - val_loss: 0.0350
# Epoch 80/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0351
# Epoch 81/100
# 344/344 - 0s - loss: 0.0332 - val_loss: 0.0350
# Epoch 82/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0347
# Epoch 83/100
# 344/344 - 0s - loss: 0.0331 - val_loss: 0.0352
# Epoch 84/100
# 344/344 - 0s - loss: 0.0331 - val_loss: 0.0346
# Epoch 85/100
# 344/344 - 0s - loss: 0.0332 - val_loss: 0.0345
# Epoch 86/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0341
# Epoch 87/100
# 344/344 - 0s - loss: 0.0328 - val_loss: 0.0341
# Epoch 88/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0343
# Epoch 89/100
# 344/344 - 0s - loss: 0.0328 - val_loss: 0.0340
# Epoch 90/100
# 344/344 - 0s - loss: 0.0328 - val_loss: 0.0342
# Epoch 91/100
# 344/344 - 0s - loss: 0.0329 - val_loss: 0.0342
# Epoch 92/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0346
# Epoch 93/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0347
# Epoch 94/100
# 344/344 - 0s - loss: 0.0330 - val_loss: 0.0342
# Epoch 95/100
# 344/344 - 0s - loss: 0.0328 - val_loss: 0.0340
# Epoch 96/100
# 344/344 - 0s - loss: 0.0328 - val_loss: 0.0342
# Epoch 97/100
# 344/344 - 0s - loss: 0.0328 - val_loss: 0.0339
# Epoch 98/100
# 344/344 - 0s - loss: 0.0327 - val_loss: 0.0343
# Epoch 99/100
# 344/344 - 0s - loss: 0.0327 - val_loss: 0.0341
# Epoch 100/100
# 344/344 - 0s - loss: 0.0328 - val_loss: 0.0347
# (39, 4) [[0.00522379 0.         0.16666667 0.3478261 ]
#  [0.00415529 0.         0.16666667 0.39130434]
#  [0.01828327 0.         0.16666667 0.43478262]
#  [0.0495073  0.         0.16666667 0.47826087]
#  [0.18212038 0.         0.16666667 0.5217391 ]
#  [0.17654042 0.         0.16666667 0.5652174 ]
#  [0.06066722 0.         0.16666667 0.6086957 ]
#  [0.04179034 0.         0.16666667 0.65217394]
#  [0.03324231 0.         0.16666667 0.6956522 ]
#  [0.0352606  0.         0.16666667 0.73913044]
#  [0.04143417 0.         0.16666667 0.7826087 ]
#  [0.04392734 0.         0.16666667 0.826087  ]
#  [0.04380862 0.         0.16666667 0.86956525]
#  [0.05259408 0.         0.16666667 0.9130435 ]
#  [0.09652143 0.         0.16666667 0.95652175]
#  [0.15291463 0.         0.16666667 1.        ]
#  [0.09925205 0.         0.33333334 0.        ]
#  [0.35818592 0.         0.33333334 0.04347826]
#  [0.19969131 0.         0.33333334 0.08695652]
#  [0.07966283 0.         0.33333334 0.13043478]
#  [0.0626855  0.         0.33333334 0.17391305]
#  [0.03561676 0.         0.33333334 0.21739131]
#  [0.01543393 0.         0.33333334 0.26086956]
#  [0.00795441 0.         0.33333334 0.30434784]
#  [0.00641102 0.         0.33333334 0.3478261 ]
#  [0.00391784 0.         0.33333334 0.39130434]
#  [0.00712335 0.         0.33333334 0.43478262]
#  [0.04380862 0.         0.33333334 0.47826087]
#  [0.19031224 0.         0.33333334 0.5217391 ]
#  [0.17832126 0.         0.33333334 0.5652174 ]
#  [0.05734299 0.         0.33333334 0.6086957 ]
#  [0.0373976  0.         0.33333334 0.65217394]
#  [0.03585421 0.         0.33333334 0.6956522 ]
#  [0.03977205 0.         0.33333334 0.73913044]
#  [0.03917844 0.         0.33333334 0.7826087 ]
#  [0.04998219 0.         0.33333334 0.826087  ]
#  [0.04832007 0.         0.33333334 0.86956525]
#  [0.0568681  0.         0.33333334 0.9130435 ]
#  [0.10103289 0.         0.33333334 0.95652175]]
# Test RMSE: 545.937
# (383, 4) [[0.08643001 0.         0.16666667 0.        ]
#  [0.06197317 0.         0.16666667 0.04347826]
#  [0.06446634 0.         0.16666667 0.08695652]
#  ...
#  [0.04832007 0.         0.33333334 0.86956525]
#  [0.0568681  0.         0.33333334 0.9130435 ]
#  [0.10103289 0.         0.33333334 0.95652175]]
# Test RMSE: 663.272

# %%
# Create traces
trace0 = go.Scatter(
    y=y_pred[1:],
    mode='lines',
    name='predicted'
)
trace1 = go.Scatter(
    y=y,

    mode='lines',
    name='real'
)

data = [trace0, trace1]

iplot(data, filename='line-mode')
# Out:
# <div>
#
#
#             <div id="eb455b7c-8b84-4f1e-abb8-f47a4bfd1a43" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eb455b7c-8b84-4f1e-abb8-f47a4bfd1a43")) {
#                     Plotly.newPlot(
#                         'eb455b7c-8b84-4f1e-abb8-f47a4bfd1a43',
#                         [{"mode": "lines", "name": "predicted", "type": "scatter", "uid": "384a9574-c32c-456a-9ad0-c49fda9912db", "y": [420.69720458984375, 422.3724060058594, 411.8519592285156, 277.6940002441406, 164.5520477294922, 96.25455474853516, 56.41892623901367, 61.76704406738281, 45.405155181884766, 92.49111938476562, 323.66766357421875, 902.8853149414062, 875.0396728515625, 407.230712890625, 314.39569091796875, 300.8033447265625, 326.68359375, 362.9267578125, 404.95361328125, 452.6838684082031, 527.9909057617188, 716.14404296875, 1066.3565673828125, 683.1596069335938, 512.8760375976562, 550.7953491210938, 520.43896484375, 327.38525390625, 232.066162109375, 136.2160186767578, 63.8566780090332, 89.84244537353516, 67.53572082519531, 84.38933563232422, 302.2909240722656, 982.3394165039062, 1181.8856201171875, 415.3322448730469, 318.5522155761719, 303.67987060546875, 303.6035461425781, 357.5697021484375, 446.4689636230469, 455.380615234375, 516.7239990234375, 796.822021484375, 1153.45849609375, 799.8723754882812, 544.216064453125, 566.091552734375, 582.5172729492188, 401.10528564453125, 281.46124267578125, 161.747314453125, 120.67717742919922, 107.9754867553711, 78.11027526855469, 98.10083770751953, 382.3992919921875, 1052.382568359375, 1024.3900146484375, 414.0884704589844, 346.3770446777344, 324.1252136230469, 394.2502136230469, 363.8758544921875, 396.6526794433594, 462.6595458984375, 527.7031860351562, 844.7404174804688, 1708.4583740234375, 992.1511840820312, 669.82666015625, 626.6689453125, 675.0331420898438, 580.8048706054688, 352.37939453125, 255.9149932861328, 181.08099365234375, 140.168212890625, 118.88261413574219, 112.15210723876953, 330.5242919921875, 1240.7000732421875, 1464.0938720703125, 490.5487060546875, 388.1708068847656, 350.6705627441406, 417.9303894042969, 423.4903564453125, 491.7942810058594, 523.3145141601562, 621.9507446289062, 945.5337524414062, 3092.26708984375, 3297.34716796875, 2724.4423828125, 1315.9273681640625, 827.7080078125, 2232.765380859375, 1204.6260986328125, 775.1041259765625, 721.5829467773438, 502.4429626464844, 317.4659423828125, 212.70887756347656, 215.22544860839844, 351.8690185546875, 457.7516784667969, 443.2500915527344, 478.17547607421875, 426.30694580078125, 533.3382568359375, 738.5990600585938, 703.9097290039062, 663.344970703125, 610.6970825195312, 669.7113647460938, 904.5687866210938, 961.6802368164062, 958.870849609375, 1073.55078125, 1056.9666748046875, 1233.13232421875, 1176.5467529296875, 928.286376953125, 939.9441528320312, 927.609375, 539.8497924804688, 327.42083740234375, 206.77561950683594, 243.40292358398438, 257.9441223144531, 293.6982727050781, 284.3431091308594, 346.14459228515625, 448.3894958496094, 524.0836791992188, 539.9276123046875, 444.731201171875, 489.44854736328125, 545.2830200195312, 643.437255859375, 415.0706481933594, 430.96075439453125, 415.6847229003906, 451.9036865234375, 312.72900390625, 215.11968994140625, 161.06674194335938, 52.73517608642578, 87.21016693115234, 55.744754791259766, 99.07671356201172, 447.8238220214844, 1985.6156005859375, 2111.536376953125, 421.234619140625, 339.9575500488281, 316.98779296875, 381.6961364746094, 381.79345703125, 447.72613525390625, 472.9375915527344, 520.3580932617188, 738.5232543945312, 1152.934326171875, 639.7521362304688, 464.95733642578125, 420.39398193359375, 415.14007568359375, 277.0308532714844, 161.21461486816406, 113.64067840576172, 71.13847351074219, 77.10733795166016, 59.395477294921875, 74.5928726196289, 305.5089416503906, 1092.1734619140625, 1151.2520751953125, 412.3442687988281, 316.3261413574219, 315.5887451171875, 356.126220703125, 364.8406982421875, 392.2479248046875, 465.30853271484375, 566.1563720703125, 942.5574340820312, 4401.60888671875, 2716.237060546875, 448.5376281738281, 622.3533325195312, 581.9288940429688, 386.95465087890625, 352.79833984375, 153.32083129882812, 85.80585479736328, 72.75173950195312, 75.04119873046875, 77.58890533447266, 339.5511169433594, 1476.148193359375, 1299.91870 ...

# %% [markdown]
# ## As you can see without any serious Hyperparameter tuning we managed to get some decent results.
